# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## axes = x = %perturbation
## axes = y = % drop in accuracy from the optimum model


# x_val = [95,90,75,50,25,95,90,75,50,25,95,90,75,50,25,95,90,75,50,25,95,90,75,50,25,95,90,75,50,25]
x_val = [95,90,75,50,25]

y_mha_p = [1.282, 0.0, 1.282, 1.282, 6.333]
y_mha_s6 = [-6.449, 1.282, 0.0, 3.885, 8.625]
y_mha_s12 = [1.282, 1.321, 1.282, 6.410, 8.625]


y_wshap_p = [7.459, 9.790, 12.005, 25.602, 45.688]
y_wshap_s6 = [4.895, 10.528, 31.235, 38.772, 37.879]
y_wshap_s12 = [10.917, 15.773, 27.273, 43.473, 49.806]

y_val_24 = [1.282, 0.0, 1.282, 1.282, 6.333, -6.449, 1.282, 0.0, 3.885, 8.625,1.282, 1.321, 1.282, 6.410, 8.625,
         7.459, 9.790, 12.005, 25.602, 45.688,4.895, 10.528, 31.235, 38.772, 37.879,10.917, 15.773, 27.273, 43.473, 49.806]

y_val_12 = [1.282, 0.0, 1.282, 1.282, 6.333, -6.449, 1.282, 0.0, 3.885, 8.625,1.282, 1.321, 1.282, 6.410, 8.625,
         10.256, 12.704, 20.085, 19.542, 33.178, 13.908, 16.239, 28.283, 44.328, 51.321, 16.239, 23.388, 33.139, 47.358, 55.284]



t_val = ['Multihead Attention - Perturbation','Multihead Attention - Perturbation','Multihead Attention - Perturbation','Multihead Attention - Perturbation','Multihead Attention - Perturbation',
        'Multihead Attention - Sequence (6)', 'Multihead Attention - Sequence (6)', 'Multihead Attention - Sequence (6)','Multihead Attention - Sequence (6)','Multihead Attention - Sequence (6)',
        'Multihead Attention - Sequence (12)','Multihead Attention - Sequence (12)','Multihead Attention - Sequence (12)','Multihead Attention - Sequence (12)','Multihead Attention - Sequence (12)',
         'Dynamic WindowSHAP - Perturbation','Dynamic WindowSHAP - Perturbation','Dynamic WindowSHAP - Perturbation','Dynamic WindowSHAP - Perturbation','Dynamic WindowSHAP - Perturbation',
        'Dynamic WindowSHAP - Sequence (6)', 'Dynamic WindowSHAP - Sequence (6)', 'Dynamic WindowSHAP - Sequence (6)','Dynamic WindowSHAP - Sequence (6)','Dynamic WindowSHAP - Sequence (6)',
        'Dynamic WindowSHAP - Sequence (12)','Dynamic WindowSHAP - Sequence (12)','Dynamic WindowSHAP - Sequence (12)','Dynamic WindowSHAP - Sequence (12)','Dynamic WindowSHAP - Sequence (12)'
        ]


# m_val  = ['mark']*30

# %%
# len(x_val),len(y_val_24),len(t_val)

# %%
# df_24 = pd.DataFrame({'x':x_val, 'y':y_val_24, 't':t_val})

# df_12 = pd.DataFrame({'x':x_val[14:], 'y':y_val_12[14:], 't':t_val[14:]})

# %%
# df
# legend_list = ['Multihead Attention - Perturbation','Multihead Attention - Sequence (6)', 'Multihead Attention - Sequence (12)',
#                'Dynamic WindowSHAP(24) - Perturbation','Dynamic WindowSHAP(24) - Sequence (6)','Dynamic WindowSHAP(24) - Sequence (12)',
#                'Dynamic WindowSHAP(12) - Perturbation','Dynamic WindowSHAP(12) - Sequence (6)','Dynamic WindowSHAP(12) - Sequence (12)']

legend_list = ['Multihead Attention - Perturbation','Multihead Attention - Sequence (6)', 'Multihead Attention - Sequence (12)',
               'Dynamic WindowSHAP(24) - Perturbation','Dynamic WindowSHAP(24) - Sequence (6)','Dynamic WindowSHAP(24) - Sequence (12)']

# %%
# import seaborn as sns


# sns.set(rc={'figure.figsize':(14.7,6.27)})

# sns.set_theme(style='white')
# # sns.set(font_scale=1.2)

# # ax.legend(frameon=False, loc='lower center', ncol=2)
# ax = sns.lineplot(data=df_24, x="x", y="y", hue="t")
# ax.invert_xaxis()
# ax1 = sns.scatterplot(data=df_24, x="x", y="y", hue="t", s=100,)



# # ax2 = sns.lineplot(data=df_12, x="x", y="y", hue="t")

# # ax3 = sns.scatterplot(data=df_12, x="x", y="y", hue="t", s=100,)
# # ax.axes.set_title("Title",fontsize=50)
# ax.set_xlabel("Top 'N' percentile features",fontsize=20)
# ax.set_ylabel("Percentage drop in MCC",fontsize=20)
# ax.tick_params(labelsize=20)
# # ax.set(xlabel='',ylabel='')
# # ax.set_title('Percentage drop in MCC for top N %ile features',fontdict = { 'fontsize': 24})
# # ax1.get_legend().set_visible(True)
# # ax1.get_legend().set_visible(True)



# ############# 
# # plt.legend(
# #     legend_list, 
# #     bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, fontsize=14)
# plt.grid()
# plt.show()
# # plt.savefig('AMIA_poster_submission_fig1c_all_together_not_best.png', dpi=600, bbox_inches='tight')

# %%
y_mha_p = [1.282, 0.0, 1.282, 1.282, 6.333]
y_mha_s6 = [-6.449, 1.282, 0.0, 3.885, 8.625]
y_mha_s12 = [1.282, 1.321, 1.282, 6.410, 8.625]


y_wshap_p = [7.459, 9.790, 12.005, 25.602, 45.688]
y_wshap_s6 = [4.895, 10.528, 31.235, 38.772, 37.879]
y_wshap_s12 = [10.917, 15.773, 27.273, 43.473, 49.806]

# %%
####### pure matplotlib
# plt.rc('font', family='Arial')
from matplotlib import cm
cus_cmap = cm.get_cmap('tab20c', 20)

# cus_cmap = cm.get_cmap('Set1', 20)

# %%
cus_cmap

# %%
fig, ax = plt.subplots(figsize=(8,6))
msize=16


ax.plot(x_val, y_mha_p,  '--o', color=cus_cmap.colors[1], linewidth=3, markersize=msize)
ax.plot(x_val, y_mha_s6,  '--o', color=cus_cmap.colors[2], linewidth=3, markersize=msize)
ax.plot(x_val, y_mha_s12,  '--o', color=cus_cmap.colors[3], linewidth=3, markersize=msize)
ax.plot(x_val, y_wshap_p,  '--o', color=cus_cmap.colors[4], linewidth=3, markersize=msize)
ax.plot(x_val, y_wshap_s6,  '--o', color=cus_cmap.colors[5], linewidth=3, markersize=msize)
ax.plot(x_val, y_wshap_s12,  '--o', color=cus_cmap.colors[6], linewidth=3, markersize=msize)


ax.set_xlabel("Top 'N' percentile features", fontsize = 24)
ax.set_ylabel('Percentage drop in MCC', color='black', fontsize = 24)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.tick_params(axis='both', which='minor', labelsize=20)
ax.invert_xaxis()
plt.tight_layout()
plt.legend(legend_list, fontsize=10,loc='upper left', borderaxespad=0.1)
plt.grid()
# plt.show()
plt.savefig('AMIA_poster_submission_fig1_matplotlib.png', dpi=600, bbox_inches='tight')
